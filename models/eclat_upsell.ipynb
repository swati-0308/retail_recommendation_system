# %%
import pandas as pd

# Load the dataset
file_path = "..dataset/Product Categorization - DATA602ProjectCleanedNew 2.csv"
df = pd.read_csv(file_path)

# Filter necessary columns
df = df[['InvoiceNo', 'Description', 'Country']]

# Group transactions by Country and InvoiceNo
transactions_by_country = df.groupby(['Country', 'InvoiceNo'])['Description'].apply(list).reset_index()

# Group the data by InvoiceNo and aggregate the product descriptions for Eclat processing
transactions = transactions_by_country.groupby('InvoiceNo')['Description'].apply(list).values.tolist()

# Convert transactions into vertical format
def transactions_to_vertical_format(transactions):
    vertical_format = {}
    for index, transaction in enumerate(transactions):
        for item in transaction:
            # Flatten if the item is a list
            if isinstance(item, list):
                for sub_item in item:
                    sub_item = str(sub_item)  # Convert to string
                    if sub_item not in vertical_format:
                        vertical_format[sub_item] = set()
                    vertical_format[sub_item].add(index)
            else:
                item = str(item)  # Convert to string
                if item not in vertical_format:
                    vertical_format[item] = set()
                vertical_format[item].add(index)
    return vertical_format

# Function to perform Eclat algorithm and find frequent itemsets
def eclat(vertical_format, min_support_count, num_transactions):
    frequent_itemsets = []

    # Calculate support for single items
    for item, transactions in vertical_format.items():
        support_count = len(transactions)
        if support_count >= min_support_count:
            support = support_count / num_transactions
            frequent_itemsets.append(((item,), support))
    return frequent_itemsets

# Convert to vertical format
vertical_format = transactions_to_vertical_format(transactions)

# Calculate the total number of transactions
num_transactions = len(transactions)

# Set minimum support to 5% of transactions
min_support = 0.02
min_support_count = min_support * num_transactions

# Find frequent itemsets
frequent_itemsets = eclat(vertical_format, min_support_count, num_transactions)

# Print the frequent itemsets with their support
for itemset, support in frequent_itemsets:
    print(f"Itemset: {itemset}, Support: {support}")
# Out:
# Itemset: ('HAND WARMER UNION JACK',), Support: 0.02534533012292485
# Itemset: ('FELTCRAFT PRINCESS CHARLOTTE DOLL',), Support: 0.02382461031554936
# Itemset: ('HOME BUILDING BLOCK WORD',), Support: 0.0423267013052845
# Itemset: ('LOVE BUILDING BLOCK WORD',), Support: 0.03402610569002661
# Itemset: ('DOORMAT NEW ENGLAND',), Support: 0.03199847928019262
# Itemset: ('JAM MAKING SET WITH JARS',), Support: 0.04821949055886453
# Itemset: ('ALARM CLOCK BAKELIKE GREEN',), Support: 0.04543150424534279
# Itemset: ('WOOD 2 DRAWER CABINET WHITE FINISH',), Support: 0.031111392725890256
# Itemset: ('WOODEN PICTURE FRAME WHITE FINISH',), Support: 0.0506906602458497
# Itemset: ('WOODEN FRAME ANTIQUE WHITE',), Support: 0.04669877075148904
# Itemset: ('JUMBO BAG PINK POLKADOT',), Support: 0.04695222405271829
# Itemset: ('JUMBO  BAG BAROQUE BLACK WHITE',), Support: 0.035356735521480165
# Itemset: ('STRAWBERRY CHARLOTTE BAG',), Support: 0.027182866556836903
# Itemset: ('LUNCH BAG RED RETROSPOT',), Support: 0.0710936509948042
# Itemset: ('STRAWBERRY LUNCH BOX WITH CUTLERY',), Support: 0.023887973640856673
# Itemset: ('JUMBO STORAGE BAG SUKI',), Support: 0.04315042453427956
# Itemset: ('JUMBO BAG PINK VINTAGE PAISLEY',), Support: 0.03301229248510962
# Itemset: ('RETROSPOT TEA SET CERAMIC 11 PC',), Support: 0.04536814092003549
# Itemset: ('JUMBO SHOPPER VINTAGE RED PAISLEY',), Support: 0.04517805094411355
# Itemset: ('COOK WITH WINE METAL SIGN',), Support: 0.03199847928019262
# Itemset: ('PAPER CHAIN KIT RETROSPOT',), Support: 0.02445824356862248
# Itemset: ('EDWARDIAN PARASOL NATURAL',), Support: 0.020022810797110633
# Itemset: ('RED TOADSTOOL LED NIGHT LIGHT',), Support: 0.02293752376124699
# Itemset: ('DOORMAT FANCY FONT HOME SWEET HOME',), Support: 0.02312761373716893
# Itemset: ('RECYCLING BAG RETROSPOT',), Support: 0.022684070460017743
# Itemset: ('WOOD BLACK BOARD ANT WHITE FINISH',), Support: 0.03548346217209479
# Itemset: ('NATURAL SLATE HEART CHALKBOARD',), Support: 0.05709035610188823
# Itemset: ('CREAM HEART CARD HOLDER',), Support: 0.026295780002534533
# Itemset: ('ENAMEL FLOWER JUG CREAM',), Support: 0.026675959954378405
# Itemset: ('JAM MAKING SET PRINTED',), Support: 0.043530604486123434
# Itemset: ('LUNCH BAG DOLLY GIRL DESIGN',), Support: 0.03484982891902167
# Itemset: ('HOMEMADE JAM SCENTED CANDLES',), Support: 0.0255987834241541
# Itemset: ('HEART OF WICKER SMALL',), Support: 0.05100747687238626
# Itemset: ('3 STRIPEY MICE FELTCRAFT',), Support: 0.023634520339627423
# Itemset: ('WOODEN BOX OF DOMINOES',), Support: 0.025281966797617537
# Itemset: ('ASSORTED COLOUR BIRD ORNAMENT',), Support: 0.06146242554809277
# Itemset: ('RETROSPOT HEART HOT WATER BOTTLE',), Support: 0.030604486123431758
# Itemset: ('HAND OVER THE CHOCOLATE   SIGN',), Support: 0.03212520593080725
# Itemset: ('TRAVEL SEWING KIT',), Support: 0.022557343809403118
# Itemset: ('ALARM CLOCK BAKELIKE IVORY',), Support: 0.0281966797617539
# Itemset: ('ALARM CLOCK BAKELIKE RED',), Support: 0.05031048029400583
# Itemset: ('ALARM CLOCK BAKELIKE ORANGE',), Support: 0.021290077303256875
# Itemset: ('HOT WATER BOTTLE TEA AND SYMPATHY',), Support: 0.028766949689519705
# Itemset: ('HAND WARMER SCOTTY DOG DESIGN',), Support: 0.025978963375997973
# Itemset: ('HAND WARMER OWL DESIGN',), Support: 0.03117475605119757
# Itemset: ('STRAWBERRY CERAMIC TRINKET BOX',), Support: 0.025155240147002916
# Itemset: ('HOT WATER BOTTLE I AM SO POORLY',), Support: 0.02952730959320745
# Itemset: ('CHOCOLATE HOT WATER BOTTLE',), Support: 0.038271448485616526
# Itemset: ('WHITE SKULL HOT WATER BOTTLE',), Support: 0.021923710556329995
# Itemset: ('SCOTTIE DOG HOT WATER BOTTLE',), Support: 0.03808135850969459
# Itemset: ('PHOTO FRAME CORNICE',), Support: 0.027563046508680775
# Itemset: ('BATHROOM METAL SIGN',), Support: 0.022684070460017743
# Itemset: ('METAL SIGN TAKE IT OR LEAVE IT',), Support: 0.02059308072487644
# Itemset: ('ASSORTED COLOUR MINI CASES',), Support: 0.020909897351413003
# Itemset: ('LUNCH BAG SPACEBOY DESIGN',), Support: 0.05816753263211253
# Itemset: ('LUNCH BAG WOODLAND',), Support: 0.04714231402864022
# Itemset: ('LUNCH BAG PINK POLKADOT',), Support: 0.05392218983652262
# Itemset: ('GUMBALL COAT RACK',), Support: 0.02800658978583196
# Itemset: ('SET OF 3 BUTTERFLY COOKIE CUTTERS',), Support: 0.02800658978583196
# Itemset: ('SET OF 3 HEART COOKIE CUTTERS',), Support: 0.029273856291978203
# Itemset: ('LUNCH BAG CARS BLUE',), Support: 0.05569636294512736
# Itemset: ('RED  HARMONICA IN BOX',), Support: 0.02654923330376378
# Itemset: ('BLUE HARMONICA IN BOX',), Support: 0.026295780002534533
# Itemset: ('SET OF 20 KIDS COOKIE CUTTERS',), Support: 0.022810797110632365
# Itemset: ('DOORMAT RED RETROSPOT',), Support: 0.03263211253326575
# Itemset: ('DOORMAT HEARTS',), Support: 0.028450133062983145
# Itemset: ('PLASTERS IN TIN SKULLS',), Support: 0.024078063616778608
# Itemset: ('4 TRADITIONAL SPINNING TOPS',), Support: 0.02027626409833988
# Itemset: ('FELTCRAFT CUSHION OWL',), Support: 0.024331516918007858
# Itemset: ('SET 2 TEA TOWELS I LOVE LONDON',), Support: 0.02116335065264225
# Itemset: ('JUMBO BAG OWLS',), Support: 0.0214168039538715
# Itemset: ('JUMBO BAG RED RETROSPOT',), Support: 0.08021796983905716
# Itemset: ('JUMBO BAG STRAWBERRY',), Support: 0.034469648967177795
# Itemset: ('ROUND SNACK BOXES SET OF4 WOODLAND',), Support: 0.028957039665441643
# Itemset: ('ROUND SNACK BOXES SET OF 4 FRUITS',), Support: 0.02325434038778355
# Itemset: ('DOLLY GIRL LUNCH BOX',), Support: 0.030160942846280573
# Itemset: ('SPACEBOY LUNCH BOX',), Support: 0.033582562412875425
# Itemset: ('6 RIBBONS RUSTIC CHARM',), Support: 0.039348625015840834
# Itemset: ('CHRISTMAS CRAFT TREE TOP ANGEL',), Support: 0.020402990748954505
# Itemset: ('CHRISTMAS CRAFT LITTLE FRIENDS',), Support: 0.024204790267393233
# Itemset: ('PAPER CHAIN KIT VINTAGE CHRISTMAS',), Support: 0.03637054872639716
# Itemset: ('SET OF 20 VINTAGE CHRISTMAS NAPKINS',), Support: 0.024965150171080978
# Itemset: ('HEART OF WICKER LARGE',), Support: 0.047078950703332914
# Itemset: ('FELTCRAFT BUTTERFLY HEARTS',), Support: 0.025725510074768723
# Itemset: ('VINTAGE HEADS AND TAILS CARD GAME',), Support: 0.0255987834241541
# Itemset: ('VINTAGE SNAP CARDS',), Support: 0.03719427195539222
# Itemset: ('FELTCRAFT 6 FLOWER FRIENDS',), Support: 0.026739323279685718
# Itemset: ('FELTCRAFT PRINCESS LOLA DOLL',), Support: 0.022303890508173867
# Itemset: ('CHILDRENS APRON SPACEBOY DESIGN',), Support: 0.025472056773539475
# Itemset: ('PACK OF 72 RETROSPOT CAKE CASES',), Support: 0.021923710556329995
# Itemset: ('HAND WARMER BIRD DESIGN',), Support: 0.026169053351919908
# Itemset: ('PLASTERS IN TIN VINTAGE PAISLEY',), Support: 0.026042326701305286
# Itemset: ('PLASTERS IN TIN SPACEBOY',), Support: 0.029654036243822075
# Itemset: ('PLASTERS IN TIN WOODLAND ANIMALS',), Support: 0.029970852870358635
# Itemset: ('GREY HEART HOT WATER BOTTLE',), Support: 0.030541122798124445
# Itemset: ('FAWN BLUE HOT WATER BOTTLE',), Support: 0.02052971739956913
# Itemset: ('CHILLI LIGHTS',), Support: 0.022177163857559246
# Itemset: ('ZINC METAL HEART DECORATION',), Support: 0.025978963375997973
# Itemset: ('CLOTHES PEGS RETROSPOT PACK 24',), Support: 0.033582562412875425
# Itemset: ('RIBBON REEL STRIPES DESIGN',), Support: 0.020339627423647193
# Itemset: ('VINTAGE UNION JACK BUNTING',), Support: 0.023381067038398175
# Itemset: ('JUMBO STORAGE BAG SKULLS',), Support: 0.02743631985806615
# Itemset: ('PINK CREAM FELT CRAFT TRINKET BOX',), Support: 0.030034216195665948
# Itemset: ('PACK OF 20 NAPKINS PANTRY DESIGN',), Support: 0.02921049296667089
# Itemset: ('ROSES REGENCY TEACUP AND SAUCER',), Support: 0.04010898491952858
# Itemset: ('GREEN REGENCY TEACUP AND SAUCER',), Support: 0.036750728678241036
# Itemset: ('RED KITCHEN SCALES',), Support: 0.025472056773539475
# Itemset: ('IVORY KITCHEN SCALES',), Support: 0.035166645545558234
# Itemset: ('JUMBO BAG WOODLAND ANIMALS',), Support: 0.026295780002534533
# Itemset: ('RED DINER WALL CLOCK',), Support: 0.024521606893929793
# Itemset: ('IVORY DINER WALL CLOCK',), Support: 0.02382461031554936
# Itemset: ('DOORMAT SPOTTY HOME SWEET HOME',), Support: 0.023064250411861616
# Itemset: ('DOORMAT ENGLISH ROSE',), Support: 0.020719807375491065
# Itemset: ('DOORMAT UNION FLAG',), Support: 0.030224306171587886
# Itemset: ('PLASTERS IN TIN STRONGMAN',), Support: 0.022557343809403118
# Itemset: ('LUNCH BOX I LOVE LONDON',), Support: 0.025408693448232163
# Itemset: ('RECIPE BOX RETROSPOT',), Support: 0.02445824356862248
# Itemset: ('RECIPE BOX PANTRY YELLOW DESIGN',), Support: 0.04644531745025979
# Itemset: ('SWEETHEART CERAMIC TRINKET BOX',), Support: 0.020086174122417946
# Itemset: ('PLEASE ONE PERSON METAL SIGN',), Support: 0.03599036877455329
# Itemset: ('ALARM CLOCK BAKELIKE PINK',), Support: 0.034976555569636296
# Itemset: ('GINGERBREAD MAN COOKIE CUTTER',), Support: 0.03041439614750982
# Itemset: ('CHARLOTTE BAG SUKI DESIGN',), Support: 0.031238119376504878
# Itemset: ('PARTY METAL SIGN',), Support: 0.021099987327334938
# Itemset: ('MEMO BOARD RETROSPOT  DESIGN',), Support: 0.020212900773032567
# Itemset: ('WOODEN SCHOOL COLOURING SET',), Support: 0.02059308072487644
# Itemset: ('AREA PATROLLED METAL SIGN',), Support: 0.020719807375491065
# Itemset: ('PAPER BUNTING RETROSPOT',), Support: 0.028766949689519705
# Itemset: ('JUMBO BAG SPACEBOY DESIGN',), Support: 0.026739323279685718
# Itemset: ('PINK FAIRY CAKE CHILDRENS APRON',), Support: 0.022747433785325052
# Itemset: ('PINK BLUE FELT CRAFT TRINKET BOX',), Support: 0.025155240147002916
# Itemset: ('RED RETROSPOT PEG BAG',), Support: 0.021543530604486123
# Itemset: ('RED RETROSPOT CHARLOTTE BAG',), Support: 0.03998225826891395
# Itemset: ('PAPER CHAIN KIT EMPIRE',), Support: 0.020086174122417946
# Itemset: ('CHARLOTTE BAG PINK POLKADOT',), Support: 0.026929413255607656
# Itemset: ('RED RETROSPOT SHOPPER BAG',), Support: 0.021860347231022682
# Itemset: ('WOODLAND CHARLOTTE BAG',), Support: 0.02743631985806615
# Itemset: ('BAKING SET SPACEBOY DESIGN',), Support: 0.0235077936890128
# Itemset: ('CHOCOLATE THIS WAY METAL SIGN',), Support: 0.021606893929793435
# Itemset: ('HOT BATHS METAL SIGN',), Support: 0.020909897351413003
# Itemset: ('POTTERING IN THE SHED METAL SIGN',), Support: 0.021923710556329995
# Itemset: ('TRADITIONAL KNITTING NANCY',), Support: 0.028703586364212393
# Itemset: ('PARTY BUNTING',), Support: 0.0762894436700038
# Itemset: ('NO SINGING METAL SIGN',), Support: 0.02116335065264225
# Itemset: ('RED RETROSPOT PICNIC BAG',), Support: 0.020973260676720316
# Itemset: ('PLASTERS IN TIN CIRCUS PARADE',), Support: 0.025788873400076035
# Itemset: ('PINK REGENCY TEACUP AND SAUCER',), Support: 0.029717399569129388
# Itemset: ('SET OF 6 SPICE TINS PANTRY DESIGN',), Support: 0.03694081865416297
# Itemset: ('SET OF 3 CAKE TINS PANTRY DESIGN',), Support: 0.06437713851222912
# Itemset: ('BAKING SET 9 PIECE RETROSPOT',), Support: 0.04739576732986947
# Itemset: ('SET OF 4 PANTRY JELLY MOULDS',), Support: 0.046635407426181726
# Itemset: ('LUNCH BAG SUKI DESIGN',), Support: 0.052781649980991004
# Itemset: ('JUMBO BAG SCANDINAVIAN BLUE PAISLEY',), Support: 0.024584970219237105
# Itemset: ('JUMBO BAG ALPHABET',), Support: 0.042199974654669875
# Itemset: ('LUNCH BAG ALPHABET DESIGN',), Support: 0.03833481181092384
# Itemset: ('JUMBO BAG APPLES',), Support: 0.03877835508807502
# Itemset: ('LUNCH BAG APPLE DESIGN',), Support: 0.049550120390318086
# Itemset: ('CHARLOTTE BAG APPLES DESIGN',), Support: 0.023064250411861616
# Itemset: ('LUNCH BAG VINTAGE LEAF DESIGN',), Support: 0.03484982891902167
# Itemset: ('DOORMAT KEEP CALM AND COME IN',), Support: 0.03770117855785072
# Itemset: ('SPOTTY BUNTING',), Support: 0.058294259282727155
# Itemset: ('LUNCH BAG DOILEY PATTERN',), Support: 0.026105690026612595
# Itemset: ('JUMBO BAG PEARS',), Support: 0.026295780002534533
# Itemset: ('JUMBO BAG DOILEY PATTERNS',), Support: 0.025091876821695603
# Itemset: ('JUMBO BAG VINTAGE LEAF',), Support: 0.044481054365733116
# Itemset: ('RABBIT NIGHT LIGHT',), Support: 0.032695475858573055
# Itemset: ('GARDENERS KNEELING PAD KEEP CALM',), Support: 0.042833607907743
# Itemset: ('GARDENERS KNEELING PAD CUP OF TEA',), Support: 0.03700418197947028
# Itemset: ('SET OF 3 WOODEN HEART DECORATIONS',), Support: 0.022177163857559246
# Itemset: ('SET OF 3 REGENCY CAKE TINS',), Support: 0.040045621594221266
# Itemset: ('SET OF TEA COFFEE SUGAR TINS PANTRY',), Support: 0.020339627423647193
# Itemset: ('SMALL WHITE HEART OF WICKER',), Support: 0.03465973894309973
# Itemset: ('LARGE WHITE HEART OF WICKER',), Support: 0.03149157267773413
# Itemset: ('POPCORN HOLDER',), Support: 0.02471169686985173
# Itemset: ('JUMBO BAG VINTAGE CHRISTMAS',), Support: 0.022240527182866558
# Itemset: ('PANTRY MAGNETIC  SHOPPING LIST',), Support: 0.02148016727917881
# Itemset: ('VINTAGE CHRISTMAS BUNTING',), Support: 0.021099987327334938
# Itemset: ('SET OF 12 FAIRY CAKE BAKING CASES',), Support: 0.02414142694208592
# Itemset: ('JUMBO BAG VINTAGE DOILY',), Support: 0.03459637561779242
# Itemset: ('LUNCH BAG VINTAGE DOILY',), Support: 0.030921302749968318
# Itemset: ('LOVE HOT WATER BOTTLE',), Support: 0.02648586997845647
# Itemset: ('HOT WATER BOTTLE KEEP CALM',), Support: 0.04010898491952858
# Itemset: ('HAND WARMER RED LOVE HEART',), Support: 0.021036624002027625
# Itemset: ('VINTAGE DOILY TRAVEL SEWING KIT',), Support: 0.020149537447725258
